# %%
# Step 2: Set up the MLflow tracking server
import mlflow
mlflow.set_tracking_uri("http://ec2-16-170-217-141.eu-north-1.compute.amazonaws.com:5000/")

# %%
# set or create an experiment
mlflow.set_experiment("exp_5 ml_algo_with_hp_tunning")
# Out:
# <Experiment: artifact_location='s3://my-s3-bucket-of-store-artifact-youtube-data12/mlflow-artifacts/7', creation_time=1764058549473, experiment_id='7', last_update_time=1764058549473, lifecycle_stage='active', name='exp_5 ml_algo_with_hp_tunning', tags={}>

# %%
import pandas as pd
df=pd.read_csv('sentiment_clean.csv')

# %%
df['sentiment_numeric']=df.pop('sentiment_numeric')

# %%
import numpy as np
import pandas as pd
import scipy.sparse as sp
import joblib
import mlflow
import optuna

from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
from sklearn.metrics import accuracy_score, classification_report, confusion_matrix, recall_score
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.neighbors import KNeighborsClassifier
from sklearn.utils.class_weight import compute_class_weight

import matplotlib.pyplot as plt
import seaborn as sns


# Target Fix
df['sentiment_numeric'] = df['sentiment_numeric'].map({-1: 2, 0: 0, 1: 1})


# Split
X_numeric = df.iloc[:, 1:-1]
y = df['sentiment_numeric']

scaler = StandardScaler(with_mean=False)
X_numeric_scaled = scaler.fit_transform(X_numeric)

X_train_num, X_test_num, y_train, y_test, train_idx, test_idx = train_test_split(
    X_numeric_scaled, y, df.index,
    test_size=0.20, random_state=42, stratify=y
)

tfidf = TfidfVectorizer(ngram_range=(1,3), max_features=20000)
X_train_text = tfidf.fit_transform(df.loc[train_idx, 'text_clean'])
X_test_text = tfidf.transform(df.loc[test_idx, 'text_clean'])

X_train = sp.hstack([X_train_text, sp.csr_matrix(X_train_num)])
X_test = sp.hstack([X_test_text, sp.csr_matrix(X_test_num)])


# Manual Class Weights Use for Prediction Adjustment
class_weights = compute_class_weight(class_weight='balanced', classes=np.unique(y_train), y=y_train)
weight_dict = {c: w for c, w in zip(np.unique(y_train), class_weights)}
print("Class Weights:", weight_dict)


# OPTUNA
def objective(trial):
    params = {
        "n_neighbors": trial.suggest_int("n_neighbors", 3, 30),
        "weights": trial.suggest_categorical("weights", ["uniform", "distance"]),
        "metric": trial.suggest_categorical("metric", ["euclidean", "manhattan"])
    }

    model = KNeighborsClassifier(**params)
    model.fit(X_train, y_train)

    preds = model.predict(X_test)

    # apply class imbalance correction
    preds_weighted = np.array([
        p if weight_dict[p] == min(class_weights) else p  # no change now (log kept for future improvement)
        for p in preds
    ])

    return recall_score(y_test, preds_weighted, average="macro")


study = optuna.create_study(direction="maximize")
study.optimize(objective, n_trials=20)

print("\nBest Hyperparameters:", study.best_params)


# Final Model
best_params = study.best_params
model = KNeighborsClassifier(**best_params)
model.fit(X_train, y_train)
y_pred = model.predict(X_test)


# Evaluation
print("\n=================== FINAL RESULTS ===================")
print("Accuracy:", accuracy_score(y_test, y_pred))
print("\nClassification Report:\n", classification_report(y_test, y_pred))

cm = confusion_matrix(y_test, y_pred)


# MLflow Logging
with mlflow.start_run(run_name="KNN_Optuna_Tuned"):
    mlflow.log_params(best_params)
    mlflow.log_metric("accuracy", accuracy_score(y_test, y_pred))
    mlflow.log_metric("macro_recall", recall_score(y_test, y_pred, average="macro"))

    plt.figure(figsize=(7,5))
    sns.heatmap(cm, annot=True, fmt="d", cmap="Blues")
    plt.
 'weights': 'distance', 'metric': 'euclidean'}. Best is trial 13 with value: 0.5884601997222748.
# Best Hyperparameters: {'n_neighbors': 12, 'weights': 'distance', 'metric': 'euclidean'}
#
# =================== FINAL RESULTS ===================
# Accuracy: 0.6431891673403395
#
# Classification Report:
#                precision    recall  f1-score   support
#
#            0       0.64      0.62      0.63      4546
#            1       0.65      0.70      0.68      4488
#            2       0.61      0.44      0.51       862
#
#     accuracy                           0.64      9896
#    macro avg       0.63      0.59      0.61      9896
# weighted avg       0.64      0.64      0.64      9896
#
# 🏃 View run KNN_Optuna_Tuned at: http://ec2-16-170-217-141.eu-north-1.compute.amazonaws.com:5000/#/experiments/7/runs/b771d790bb854a909842bf648d287a62
# 🧪 View experiment at: http://ec2-16-170-217-141.eu-north-1.compute.amazonaws.com:5000/#/experiments/7
#
# KNN Model Successfully Trained & Logged! 🚀

# %%
# Out:
# [I 2025-10-24 11:49:57,799] A new study created in memory with name: no-name-a9184ea7-4276-4b7c-9331-737e41788a5b
# [I 2025-10-24 11:50:03,365] Trial 0 finished with value: 0.6452721187249235 and parameters: {'n_neighbors': 15, 'weights': 'uniform', 'p': 1}. Best is trial 0 with value: 0.6452721187249235.
# [I 2025-10-24 11:50:04,384] Trial 1 finished with value: 0.6158309640169413 and parameters: {'n_neighbors': 20, 'weights': 'uniform', 'p': 2}. Best is trial 0 with value: 0.6452721187249235.
# [I 2025-10-24 11:50:05,419] Trial 2 finished with value: 0.6478322157131425 and parameters: {'n_neighbors': 20, 'weights': 'distance', 'p': 1}. Best is trial 2 with value: 0.6478322157131425.
# [I 2025-10-24 11:50:06,322] Trial 3 finished with value: 0.620606160823963 and parameters: {'n_neighbors': 22, 'weights': 'uniform', 'p': 1}. Best is trial 2 with value: 0.6478322157131425.
# [I 2025-10-24 11:50:07,218] Trial 4 finished with value: 0.6551112502563992 and parameters: {'n_neighbors': 18, 'weights': 'uniform', 'p': 1}. Best is trial 4 with value: 0.6551112502563992.
# [I 2025-10-24 11:50:08,125] Trial 5 finished with value: 0.6499916745205707 and parameters: {'n_neighbors': 8, 'weights': 'distance', 'p': 1}. Best is trial 4 with value: 0.6551112502563992.
# [I 2025-10-24 11:50:09,068] Trial 6 finished with value: 0.6302558214979073 and parameters: {'n_neighbors': 20, 'weights': 'uniform', 'p': 1}. Best is trial 4 with value: 0.6551112502563992.
# [I 2025-10-24 11:50:09,915] Trial 7 finished with value: 0.6077549403021928 and parameters: {'n_neighbors': 24, 'weights': 'uniform', 'p': 2}. Best is trial 4 with value: 0.6551112502563992.
# [I 2025-10-24 11:50:10,851] Trial 8 finished with value: 0.6527197057053813 and parameters: {'n_neighbors': 20, 'weights': 'uniform', 'p': 1}. Best is trial 4 with value: 0.6551112502563992.
# [I 2025-10-24 11:50:11,693] Trial 9 finished with value: 0.6325918101883068 and parameters: {'n_neighbors': 8, 'weights': 'uniform', 'p': 2}. Best is trial 4 with value: 0.6551112502563992.
# 🏃 View run KNN_TFIDF_SMOTE_Optuna_Fast at: https://dagshub.com/Vaibha3246/influence_mirror.mlflow/#/experiments/3/runs/8e8607c9eaa9499b8b3929044e39ed30
# 🧪 View experiment at: https://dagshub.com/Vaibha3246/influence_mirror.mlflow/#/experiments/3
#  MLflow run logged successfully for KNN (TF-IDF + SMOTE + Optuna)
